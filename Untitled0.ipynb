# %%
# Load the csv file
import pandas as pd
df = pd.read_csv('films.csv')

# %%
# Check the possible null value(s)
df.isnull()
# Out:
#       Unnamed: 0   Year  Length  Title  Subject  Actor  Actress  Director  \
# 0          False  False   False  False    False  False    False     False
# 1          False  False   False  False    False  False    False     False
# 2          False  False   False  False    False  False    False     False
# 3          False  False   False  False    False  False    False     False
# 4          False  False   False  False    False  False    False     False
# ...          ...    ...     ...    ...      ...    ...      ...       ...
# 1654       False  False   False  False    False  False    False     False
# 1655       False  False   False  False    False  False    False     False
# 1656       False  False   False  False    False  False    False     False
# 1657       False  False   False  False    False  False    False     False
# 1658       False  False   False  False    False  False    False     False
#
#       Popularity  Awards
# 0          False   False
# 1          False   False
# ...

# %%
# Get the sum of null values for each column
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Year           0
# Length        67
# Title          0
# Subject        2
# Actor          8
# Actress        0
# Director       0
# Popularity     6
# Awards         0
# dtype: int64

# %%
# Get data statistics such as count, mean, std, etc.
df.describe()
# Out:
#         Unnamed: 0         Year       Length   Popularity
# count  1659.000000  1659.000000  1592.000000  1653.000000
# mean    829.000000  1975.802893   105.179648    43.110103
# std     479.056364    17.057848    30.629501    26.747406
# min       0.000000  1920.000000     5.000000     0.000000
# 25%     414.500000  1967.000000    90.000000    19.000000
# 50%     829.000000  1983.000000   102.000000    43.000000
# 75%    1243.500000  1989.000000   116.000000    67.000000
# max    1658.000000  1997.000000   450.000000    88.000000

# %%
# Determine the average popularity for each movie subject
subject_pop = df.groupby('Subject').Popularity.mean()
subject_pop
# Out:
# Subject
# Action             38.950980
# Adventure          63.500000
# Comedy             42.828571
# Crime              66.000000
# Drama              44.150307
# Fantasy            57.000000
# Horror             46.526316
# Music              46.139535
# Mystery            40.691589
# Romance            62.000000
# Science Fiction    42.500000
# Short              62.000000
# War                41.294118
# Western            44.271186
# Westerns           38.500000
# Name: Popularity, dtype: float64

# %%
# Identify the top 3 most popular subjects
top_subjects = subject_pop.sort_values(ascending=False).head(3)
top_subjects
# Out:
# Subject
# Crime        66.0
# Adventure    63.5
# Romance      62.0
# Name: Popularity, dtype: float64

# %%
# Inspect the first 5 rows
df.head(5)
# Out:
#    Unnamed: 0  Year  Length                    Title Subject  \
# 0           0  1990   111.0  Tie Me Up! Tie Me Down!  Comedy
# 1           1  1991   113.0               High Heels  Comedy
# 2           2  1983   104.0           Dead Zone, The  Horror
# 3           3  1979   122.0                     Cuba  Action
# 4           4  1978    94.0           Days of Heaven   Drama
#
#                  Actor          Actress           Director  Popularity Awards
# 0    Banderas, Antonio  Abril, Victoria   Almodóvar, Pedro        68.0     No
# 1         Bosé, Miguel  Abril, Victoria   Almodóvar, Pedro        68.0     No
# 2  Walken, Christopher    Adams, Brooke  Cronenberg, David        79.0     No
# 3        Connery, Sean    Adams, Brooke    Lester, Richard         6.0     No
# 4        Gere, Richard    Adams, Brooke   Malick, Terrence        14.0     No

# %%
# Inspect the last 5 rows
df.tail(5)
# Out:
#       Unnamed: 0  Year  Length                     Title Subject  \
# 1654        1654  1932   226.0  Shadow of the Eagle, The  Action
# 1655        1655  1989   103.0              Blood & Guns  Action
# 1656        1656  1988    78.0                 Hot Money   Drama
# 1657        1657  1977    75.0            Comedy Tonight  Comedy
# 1658        1658  1991    65.0            Robin Williams  Comedy
#
#                 Actor Actress Director  Popularity Awards
# 1654      Wayne, John      \N       \N        19.0     No
# 1655    Welles, Orson      \N       \N        43.0     No
# 1656    Welles, Orson      \N       \N        19.0     No
# 1657  Williams, Robin      \N       \N        18.0     No
# 1658  Williams, Robin      \N       \N         4.0     No

# %%
# Remove the records having nulls in Length, Subject, Populairty and Actor
df.dropna(subset=['Length', 'Subject', 'Popularity', 'Actor'])
# Out:
#       Unnamed: 0  Year  Length                     Title Subject  \
# 0              0  1990   111.0   Tie Me Up! Tie Me Down!  Comedy
# 1              1  1991   113.0                High Heels  Comedy
# 2              2  1983   104.0            Dead Zone, The  Horror
# 3              3  1979   122.0                      Cuba  Action
# 4              4  1978    94.0            Days of Heaven   Drama
# ...          ...   ...     ...                       ...     ...
# 1654        1654  1932   226.0  Shadow of the Eagle, The  Action
# 1655        1655  1989   103.0              Blood & Guns  Action
# 1656        1656  1988    78.0                 Hot Money   Drama
# 1657        1657  1977    75.0            Comedy Tonight  Comedy
# 1658        1658  1991    65.0            Robin Williams  Comedy
#
#                     Actor          Actress           Director  Popularity  \
# 0       Banderas, Antonio  Abril, Victoria   Almodóvar, Pedro        68.0
# ...

# %%
# Replace nulls in Directory columns with 'Unknown'
df['Actress'] = df['Actress'].replace('\\N', 'Unknown')
df
# Out:
#       Unnamed: 0  Year  Length                     Title Subject  \
# 0              0  1990   111.0   Tie Me Up! Tie Me Down!  Comedy
# 1              1  1991   113.0                High Heels  Comedy
# 2              2  1983   104.0            Dead Zone, The  Horror
# 3              3  1979   122.0                      Cuba  Action
# 4              4  1978    94.0            Days of Heaven   Drama
# ...          ...   ...     ...                       ...     ...
# 1654        1654  1932   226.0  Shadow of the Eagle, The  Action
# 1655        1655  1989   103.0              Blood & Guns  Action
# 1656        1656  1988    78.0                 Hot Money   Drama
# 1657        1657  1977    75.0            Comedy Tonight  Comedy
# 1658        1658  1991    65.0            Robin Williams  Comedy
#
#                     Actor          Actress           Director  Popularity  \
# 0       Banderas, Antonio  Abril, Victoria   Almodóvar, Pedro        68.0
# ...

# %%
# Replace nulls in Directory columns with 'Unknown'
df['Director'] = df['Director'].replace('\\N', 'Unknown')
df
# Out:
#       Unnamed: 0  Year  Length                     Title Subject  \
# 0              0  1990   111.0   Tie Me Up! Tie Me Down!  Comedy
# 1              1  1991   113.0                High Heels  Comedy
# 2              2  1983   104.0            Dead Zone, The  Horror
# 3              3  1979   122.0                      Cuba  Action
# 4              4  1978    94.0            Days of Heaven   Drama
# ...          ...   ...     ...                       ...     ...
# 1654        1654  1932   226.0  Shadow of the Eagle, The  Action
# 1655        1655  1989   103.0              Blood & Guns  Action
# 1656        1656  1988    78.0                 Hot Money   Drama
# 1657        1657  1977    75.0            Comedy Tonight  Comedy
# 1658        1658  1991    65.0            Robin Williams  Comedy
#
#                     Actor          Actress           Director  Popularity  \
# 0       Banderas, Antonio  Abril, Victoria   Almodóvar, Pedro        68.0
# ...

# %%
# Explore the trend of average movie lengths over the years between 1980 and 2000 with award staus breakdown
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Length', 'Title', 'Subject', 'Actor', 'Actress',
#        'Director', 'Popularity', 'Awards'],
#       dtype='object')

# %%
# Filter the movies based on the 'Year' column from 1980 to 2000
df_1980_2000 = df[(df['Year'] > 1979) & (df['Year'] < 1999)]
df_1980_2000
# Out:
#       Unnamed: 0  Year  Length                    Title  Subject  \
# 0              0  1990   111.0  Tie Me Up! Tie Me Down!   Comedy
# 1              1  1991   113.0               High Heels   Comedy
# 2              2  1983   104.0           Dead Zone, The   Horror
# 5              5  1983   140.0                Octopussy   Action
# 6              6  1984   101.0             Target Eagle   Action
# ...          ...   ...     ...                      ...      ...
# 1652        1652  1991    52.0        Riders of Destiny  Western
# 1653        1653  1990     NaN          Sagebrush Trail  Western
# 1655        1655  1989   103.0             Blood & Guns   Action
# 1656        1656  1988    78.0                Hot Money    Drama
# 1658        1658  1991    65.0           Robin Williams   Comedy
#
#                     Actor          Actress                  Director  \
# 0       Banderas, Antonio  Abril, Victoria          Almodóvar, Pedro
# ...

# %%
# Group the data by 'Year' and 'Awards' to calculate the average 'Length'
df_1980_2000_awards = df_1980_2000.groupby(['Year', 'Awards']).Length.mean().reset_index()
df_1980_2000_awards
# Out:
#     Year Awards      Length
# 0   1980     No  109.481481
# 1   1980    Yes  142.500000
# 2   1981     No  110.000000
# 3   1981    Yes  131.400000
# 4   1982     No  115.206897
# 5   1982    Yes  154.000000
# 6   1983     No  100.285714
# 7   1983    Yes  112.500000
# 8   1984     No  101.666667
# 9   1984    Yes  126.750000
# 10  1985     No  101.428571
# 11  1985    Yes  118.714286
# 12  1986     No  100.579545
# 13  1986    Yes  120.166667
# 14  1987     No  100.294737
# 15  1987    Yes  122.800000
# 16  1988     No  102.500000
# 17  1988    Yes  123.500000
# 18  1989     No   99.067416
# 19  1989    Yes  112.000000
# 20  1990     No   98.816092
# 21  1990    Yes  134.000000
# 22  1991     No  103.745763
# 23  1991    Yes  118.000000
# 24  1992     No  104.951220
# 25  1992    Yes  134.000000
# 26  1993     No   79.933333
# 27  1996     No   96.000000
# 28  1997     No  109.000000

# %%
import plotly.express as px

# %%
fig = px.line(df_1980_2000_awards, x='Year', y = 'Length', color = 'Awards')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
